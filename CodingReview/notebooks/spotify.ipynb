# %%
import os
from dotenv import load_dotenv
import requests
import base64

load_dotenv()

CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")
AUTH_URL = 'https://accounts.spotify.com/api/token'

client_creds = f"{CLIENT_ID}:{CLIENT_SECRET}"
client_creds_b64 = base64.b64encode(client_creds.encode()).decode()

headers = {
    'Authorization': f'Basic {client_creds_b64}'
}
payload = {
    'grant_type': 'client_credentials'
}

auth_response = requests.post(AUTH_URL, data=payload, headers=headers)
auth_response_data = auth_response.json()

# Extract the token
access_token = auth_response_data['access_token']

# %%
import requests

# Base URL for the Spotify API
BASE_URL = 'https://api.spotify.com/v1/search'

# Headers for the API request
headers = {
    'Authorization': f'Bearer {access_token}'
}

# Query parameters for searching an artist
params = {
    'q': 'Kendrick Lamar',
    'type': 'artist',
    'limit': 5
}

# Make the GET request
response = requests.get(BASE_URL, headers=headers, params=params)
artist_info = response.json()

# Print results (example)
for artist in artist_info['artists']['items']:
    print(f"Artist: {artist['name']}")
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=5&query=Kendrick%20Lamar&type=artist', 'limit': 5, 'next': 'https://api.spotify.com/v1/search?offset=5&limit=5&query=Kendrick%20Lamar&type=artist', 'offset': 0, 'previous': None, 'total': 11, 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'}, 'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg', 'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb39ba6dcd4355c03de0b50918', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab6761610000517439ba6dcd4355c03de0b50918', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f17839ba6dcd4355c03de0b50918', 'height': 160, 'width': 160}], 'name': 'Kendrick Lamar', 'type': 'artist', 'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebc7688aad1bf03986934d7e26', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174c7688aad1bf03986934d7e26', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178c7688aad1bf03986934d7e26', 'height': 160, 'width': 160}], 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4293385d324db8558179afd9', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab676161000051744293385d324db8558179afd9', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f1784293385d324db8558179afd9', 'height': 160, 'width': 160}], 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/64Ttrc7SkxLn0fJ81yUws6'}, 'href': 'https://api.spotify.com/v1/artists/64Ttrc7SkxLn0fJ81yUws6', 'id': '64Ttrc7SkxLn0fJ81yUws6', 'images': [], 'name': 'Kendrick Lamar Duckworth', 'type': 'artist', 'uri': 'spotify:artist:64Ttrc7SkxLn0fJ81yUws6'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3T913bfZT1NlIHJkbmHY2D'}, 'href': 'https://api.spotify.com/v1/artists/3T913bfZT1NlIHJkbmHY2D', 'id': '3T913bfZT1NlIHJkbmHY2D', 'images': [], 'name': 'Kendrick Lamar Jackson', 'type': 'artist', 'uri': 'spotify:artist:3T913bfZT1NlIHJkbmHY2D'}]}}
# Artist: Kendrick Lamar
# Artist: Bruno Mars
# Artist: Drake
# Artist: Kendrick Lamar Duckworth
# Artist: Kendrick Lamar Jackson

# %%
print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3T913bfZT1NlIHJkbmHY2D'}, 'href': 'https://api.spotify.com/v1/artists/3T913bfZT1NlIHJkbmHY2D', 'id': '3T913bfZT1NlIHJkbmHY2D', 'images': [], 'name': 'Kendrick Lamar Jackson', 'type': 'artist', 'uri': 'spotify:artist:3T913bfZT1NlIHJkbmHY2D'}
